# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class node:
    def __init__(self, item):
        self.item = item
        self.leftPointer = None
        self.rightPointer = None

# %%
#new_instance is an object
new_instance = node(None)

# %%
new_instance

# %%
new_instance.item = 45

# %%
new_instance.leftPointer = 1

# %%
new_instance.rightPointer = 0

# %%
print(new_instance.item)
# Out:
# 45

# %%
MyTree = [node(None) for i in range(9)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for i in range(9):
    print("Node ", i)
    MyTree[i].item = int(input("Enter the node "))
    MyTree[i].leftPointer = int(input("Enter the left pointer  "))
    MyTree[i].rightPointer = int(input("Enter the right pointer "))
# Out:
# Node  0
# Enter the node 27
# Enter the left pointer  1
# Enter the right pointer 2
# Node  1
# Enter the node 19
# Enter the left pointer  4
# Enter the right pointer 6
# Node  2
# Enter the node 36
# Enter the left pointer  -1
# Enter the right pointer 3
# Node  3
# Enter the node 42
# Enter the left pointer  -1
# Enter the right pointer 5
# Node  4
# Enter the node 16
# Enter the left pointer  -1
# Enter the right pointer 7
# Node  5
# Enter the node 89
# Enter the left pointer  8
# Enter the right pointer -1
# Node  6
# Enter the node 21
# Enter the left pointer  -1
# Enter the right pointer -1
# Node  7
# Enter the node 17
# Enter the left pointer  -1
# Enter the right pointer -1
# Node  8
# Enter the node 55
# Enter the left pointer  -1
# Enter the right pointer -1

# %% [markdown]
# # Finding an item in a binary tree
# The algorithm to find if an item is in the binary tree myTree and return the pointer to its node if found or a null pointer if not found, could be written as a function in pseudocode, as shown.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
MyTree[0].item
# Out:
# 27

# %%
nullPointer = -1
rootPointer = 0
def find(itemSearch):
    global rootPointer, nullPointer
    itemPointer = rootPointer 
    while MyTree[itemPointer].item != itemSearch and itemPointer != nullPointer:
        if MyTree[itemPointer].item > itemSearch:
            itemPointer = MyTree[itemPointer].leftPointer
        else:
            itemPointer = MyTree[itemPointer].rightPointer
    return itemPointer

# %%
find(100)
# Out:
# -1

# %% [markdown]
# # Part 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Node:
    def __init__(self, item):
        self.item = item
        self.leftPointer = None
        self.rigthPointer = None
        self.oldPointer = None
        self.leftBranch = True

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Node:
    def __init__(self, item=None, left_pointer=None, right_pointer=None):
        self.item = item
        self.left_pointer = left_pointer
        self.right_pointer = right_pointer

# %%
# Constants
null_pointer = -1

# Initialize tree and pointers
my_tree = [Node(None) for i in range(12)]
root_pointer = null_pointer
next_free_pointer = 0

# %%
def node_add(item_add):
    global root_pointer, next_free_pointer
    if next_free_pointer == null_pointer:
        print("No nodes free")
        return
    item_add_pointer = next_free_pointer
    next_free_pointer = my_tree[next_free_pointer].left_pointer
    item_pointer = root_pointer
    if item_pointer == null_pointer:
        root_pointer = item_add_pointer
    else:
        while item_pointer != null_pointer:
            old_pointer = item_pointer
            if my_tree[item_pointer].item > item_add:
                left_branch = True
                item_pointer = my_tree[item_pointer].left_pointer
            else:
                left_branch = False
                item_pointer = my_tree[item_pointer].right_pointer
        if left_branch:
            my_tree[old_pointer].left_pointer = item_add_pointer
        else:
            my_tree[old_pointer].right_pointer = item_add_pointer
    my_tree[item_add_pointer].left_pointer = null_pointer
    my_tree[item_add_pointer].right_pointer = null_pointer
    my_tree[item_add_pointer].item = item_add


# Example usage
node_add()

# %%
def dummy(radius, pi=None):
    if pi != None:
        return pi *radius**2
    else:
        return None

# %%
dummy(3)

# %%
node_add()
# Out:
# -1
