# %% [markdown]
# # Binary Tree

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class node:
    def __init__(self, item):
        self.item = item
        self.leftPointer = None
        self.rightPointer = None

# %%
# Constants
null_pointer = -1

# Initialize tree and pointers
my_tree = [Node(None) for i in range(12)]
root_pointer = null_pointer
next_free_pointer = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 null_pointer = -1
#       4 # Initialize tree and pointers
# ----> 5 my_tree = [Node(None) for i in range(12)]
#       6 root_pointer = null_pointer
#       7 next_free_pointer = 0
#
# Cell In[1], line 5, in <listcomp>(.0)
#       2 null_pointer = -1
#       4 # Initialize tree and pointers
# ----> 5 my_tree = [Node(None) for i in range(12)]
#       6 root_pointer = null_pointer
#       7 next_free_pointer = 0
#
# NameError: name 'Node' is not defined
